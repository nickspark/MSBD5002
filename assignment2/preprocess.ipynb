# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv("./data/trainFeatures.csv")
label = pd.read_csv("./data/trainLabels.csv", header=None)

# %%
print(label.sum(),len(label)-label.sum())
# Out:
# 0    8168
# dtype: int64 0    26021
# dtype: int64

# %%
for colnm in train_data.columns:
    if(is_number(train_data[colnm].values[1])!=True):
        col_sets = train_data[colnm].drop_duplicates().tolist()
        #print(col_sets)
        set_1 = []
        set_2 = []
        for col_set in col_sets:
            #print(train_data[colnm] == col_set)
            len_1 = int(label[train_data[colnm] == col_set].sum())
            len_2 = int(len(label[train_data[colnm] == col_set]))-len_1
            set_1.append(len_1/100.0)
            set_2.append(len_2/100.0)

        rects1 = plt.bar(range(len(set_1)), height=set_1, width=0.5,color='red', label="1")
        rects2 = plt.bar(range(len(set_2)), height=set_2, width=0.5,color='green', label="0",bottom = set_1)
        #plt.ylim(0, 80)
        print(len(col_sets))
        plt.ylabel("label")
        plt.xticks(range(len(col_sets)), col_sets)
        plt.xlabel(colnm)
        plt.legend(loc = 0)
        plt.xticks(rotation=90)
        plt.tight_layout()

        plt.show()
# Out:
# 9
# 16
# 7
# 15
# 6
# 5
# 2
# 42

# %%
countries
# Out:
# 0                      United-States
# 3                             Mexico
# 5                        El-Salvador
# 12                           Germany
# 46                       Philippines
# 69                             Italy
# 71                                 ?
# 126                          Jamaica
# 175                           Canada
# 178                            South
# 225                         Columbia
# 233                            China
# 251                             Hong
# 262                        Nicaragua
# 295                      Puerto-Rico
# 298                            India
# 306               Dominican-Republic
# 365                            Haiti
# 449                          England
# 459                  Trinadad&Tobago
# 494                           Taiwan
# 549                             Cuba
# 572                           France
# 648                             Iran
# 712                          Vietnam
# ...

# %%
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        pass
 
    try:
        import unicodedata
        unicodedata.numeric(s)
        return True
    except (TypeError, ValueError):
        pass
 
    return False
